# %% [markdown]
# ### 1. Ler e exibir um arquivo CSV usando pandas

# %%
df = spark.read.csv("/FileStore/tables/retail.csv", header=True, sep=";")
df = df.toPandas()
display(df.head(5))

#display(dbutils.fs.ls("/FileStore/tables"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ### 2. Selecionar colunas específicas de um DataFrame usando pandas

# %%
df_unit_price = df["unit_price"]
display(df_unit_price)
# Out:
# 0         2,55
# 1         3,39
# 2         2,75
# 3         3,39
# 4         3,39
#           ...
# 541904    0,85
# 541905     2,1
# 541906    4,15
# 541907    4,15
# 541908    4,95
# Name: unit_price, Length: 541909, dtype: object

# %% [markdown]
# ### 3. Filtrar linhas com base em uma condição usando pandas

# %%
filtro1 = df[df["unit_price"] == "2,55"]
filtro2 = df.query('unit_price == "2,55"')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>536371</td>
#       <td>22086</td>
# ...

# %% [markdown]
# ### 4. Agrupar dados com base em uma coluna usando pandas

# %%
minimo = df.unit_price.min()
maximo = df.unit_price.max()
df.agg({"unit_price" : ['min', 'max']})
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unit_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>min</th>
#       <td>-11062,06</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>99,96</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 5. Usar a função max em alguma coluna do DataFrame

# %%
maximo = df.unit_price.max()
maximo
# Out:
# Out[25]: '99,96'

# %%
teste = {"WHITE METAL LANTERN":"oooooooi"}


df["description"].map(teste)
# Out:
# Out[15]: 0              NaN
# 1         oooooooi
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 541904         NaN
# 541905         NaN
# 541906         NaN
# 541907         NaN
# 541908         NaN
# Name: description, Length: 541909, dtype: object

# %%
#filtro1 = df[df["unit_price"] == "2,55"]
#filtro2 = df.query('unit_price == "2,55"')

# def percentage_marks(x):
#   if x == "United Kingdom":
#     return "PORRA"

# df['region'] = (df['region'].apply(percentage_marks))
# display(df['region'])
# for i in df['region']:
#   if i == "United Kingdom":
#     print("VAI SE FODER")

updated = df['region'] == "United Kingdom"
df.loc[updated, 'region'] = 'POOOOORRA'
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,55</td>
#       <td>17850</td>
#       <td>POOOOORRA</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
# ...
